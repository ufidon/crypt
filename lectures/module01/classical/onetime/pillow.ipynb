# %%
# Packages
# pip install --user numpy scipy matplotlib ipython jupyter pandas sympy nose pillow

# %matplotlib inline
# Reference: 
# 1. https://matplotlib.org/tutorials/introductory/images.html
# 2. https://numpy.org/doc/stable/user/quickstart.html

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
ds = mpimg.imread('./dragonship.jpg')

# %%
print(ds)
# Out:
# [[[ 48  51  56]
#   [ 48  51  56]
#   [ 47  50  55]
#   ...
#   [ 99 103 106]
#   [ 96 100 103]
#   [ 94  98 101]]
#
#  [[ 48  51  56]
#   [ 48  51  56]
#   [ 47  50  55]
#   ...
#   [ 96 100 103]
#   [ 94  98 101]
#   [ 92  96  99]]
#
#  [[ 48  51  56]
#   [ 48  51  56]
#   [ 47  50  55]
#   ...
#   [ 96 100 103]
#   [ 95  99 102]
#   [ 94  98 101]]
#
#  ...
#
#  [[177 138 131]
#   [174 135 128]
#   [172 133 126]
#   ...
#   [ 49  35  26]
#   [ 51  37  28]
#   [ 52  38  29]]
#
#  [[174 135 128]
#   [175 136 129]
#   [175 136 129]
#   ...
#   [ 34  20  11]
#   [ 38  24  15]
#   [ 42  28  19]]
#
#  [[171 132 125]
#   [175 136 129]
#   [178 139 132]
#   ...
#   [ 35  21  12]
#   [ 35  21  12]
#   [ 32  18   9]]]

# %%
impplot = plt.imshow(ds)

# %%
ds.shape
# Out:
# (900, 1600, 3)

# %%
# https://stackoverflow.com/questions/51991997/the-image-saved-as-jpeg-with-pillow-is-different-from-the-original-image
mpimg.imsave('./newdrag.png',ds)

# %%
nds = mpimg.imread('./newdrag.png')

# %%
mpimg.imsave('./dragon2.png',nds)

# %%
ds2 = mpimg.imread('./dragon2.png')

# %%
ds2.shape == nds.shape
# Out:
# False
